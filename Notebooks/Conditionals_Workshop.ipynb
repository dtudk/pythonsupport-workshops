# %% [markdown]
# # Workshop: Conditionals
# ### DTU Python Support

# %% [markdown]
# ### Timetable in person Workshop

# %% [markdown]
# | Time | Exercise | Description | Materials |
# |-|-|-|-|
# | 00:00 - 05:00 | Introduction | Introduce computational thinking and conditionals | - |
# | 05:00 - 10:00 | Exercise 1 | Play dice game and talk about the conditions of the game | Dice |
# | 10:00 - 15:00 | Exercise 2 | Conditional computer exercise 1 | PC |
# | 15:00 - 20:00 | Exercise 3 | Play snakes and Ladders and talk about the conditions of this game | Snakes and Ladders |
# | 20:00 - 25:00 | Exercise 4 | Conditional computer exercise 2 | PC |
# | 25:00 - 30:00 | Reflection | Reflect on the workshop with the student. Remember what they did well and less well and talk it through with them.  | Tablet |

# %% [markdown]
# ### Introduction

# %% [markdown]
# #### Disclaimer
# DTU Python Support workshops are intented to be done by students with the help from a python supporter. Therefore if you are having any trouble with the workshop, please do not hesitate to reach out to us either in person, on discord or via our webside.
#
# If you get stuck at any point, you can also try some of our other workshops, as we use the principals tought in earlier wokshops. The recomended order to do the workshops are as follows:
# - Variables
# - Conditionals
# - Loops
# - Functions
#
# #### Computational Thinking
#
# When programming it is important to understand how a computer works. This is called computational thinking. With our workshops we try to convey how to computer thinks, and therefore make your life easier.
#
# If you would like to read more:
# https://www.bbc.co.uk/bitesize/guides/zp92mp3/revision/1
#
# #### Conditionals
#
# Conditionals are a way of telling the computer what to do if something is true or false. This is done with if-statements. You can think of an if-statement as a question: if the answer is “yes” the condition is true and the computer runs the specified command. If the answer is “no” it skips to the next command.
# This is a good tool if you want to generalize your code to handle different cases or exceptions. The goal of your program may for example depend on what the user asks for, or how much input is received.

# %% [markdown]
# ### Exercise 1: Dice Game

# %% [markdown]
# Imagine that two people, player 1 and player 2 play a game of dice. The winner of the game is the person who rolls the highest number. If they the same number it's a tie and they roll again. We want to visualize this as a bunch of scenarios using the velcro cards. The trick here is the break it down into every possible scenario, and telling the computer what to do in each scenario. For example, one scenario is player 1 rolling higher than player 2. We want to make every scenario as a velcro card

# %% [markdown]
# ### Exercise 2: Conditionals in python

# %% [markdown]
# Now we will code the dice game in python

# %%
player1_roll = 5
player2_roll = 2
### remove this for the student version ####
if player1_roll > player2_roll:
    print("Player 1 Wins!")
elif player1_roll < player2_roll:
    print("player 2 wins!")
else:
    print("Rematch")
###########################################

# %% [markdown]
# Note that just as with the velcro cards, the order of the if statements does not really matter. We could just as well have gotten the same outputs by doing it in a different order.

# %%
player1_roll = 5
player2_roll = 2
### remove this for the student version ####
if player1_roll < player2_roll:
    print("Player 1 Wins!")
elif player1_roll > player2_roll:
    print("player 2 wins!")
else:
    print("Rematch")
#############################################

# %% [markdown]
# ### Exercise 3: Snakes and Ladders

# %% [markdown]
# Now we want to program the game snakes and ladders. More concretely, we will try and tell the computer what to do, after someone has thrown their die. As in the dice game, we will break it down into every possible scenario. Think of what can happen after you've thrown. How many scenarios are there? What happens in each scenario? We want to transfer this to the velcro cards

# %% [markdown]
# ### Exercise 4: Programming snakes and ladders

# %% [markdown]
# Now we want to transfer what we just did with the velcro cards onto the computer. We have helped a bit by already defining a list of the different positions. Your job is to assume that you are given a current position and a throw, and then make the computer print, which square you should move to

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
positions = [
    "1",
    "2",
    "3",
    "ladder",
    "5",
    "6",
    "7",
    "snake",
    "9",
    "ladder",
    "11",
    "12",
    "13",
    "14",
    "15",
    "16",
    "17",
    "18",
    "ladder",
    "20",
    "21",
    "22",
    "23",
    "snake",
    "25",
]

# %% [markdown]
# Below is an example of how to use the list with an if-statement (remember that python is 0-indexed):

# %%
if positions[4] == "ladder":
    print("position is a ladder")

# %%
if positions[3] == "ladder":
    print("position is a ladder")

# %%
current_position = 3
roll = 5

### remove this for the student version ####
if positions[current_position + roll - 1] == "snake":
    print("Go to square number:")
    print(current_position + roll - 6)
elif positions[current_position + roll - 1] == "ladder":
    print("Go to square number:")
    print(current_position + roll + 3)
else:
    print("Go to square number:")
    print(current_position + roll)
###########################################

# %% [markdown]
# ### Extra Exercises for futher practice

# %% [markdown]
# 1. Can you modify the snakes and ladders part to also print a message, if the player wins?
# 2. Can you change the order of the if-statements?
# 3. Can you get rid og the elif and else statements?
